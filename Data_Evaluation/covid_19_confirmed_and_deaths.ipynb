# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import csv

# %%
covidtotal = pd.read_csv("Resources/covid_19_data.csv") 
covidtotal.head()
# Out:
#                        Date  NY Total Cases  NY Actual Cases  NY Total Deaths  \
# 0  Break 0: 1/22/20-4/22/20          114784           114784             4260
# 1                   4/29/20          134850            20066             5170
# 2                    5/6/20          145627            10777             6482
# 3                   5/13/20          153411             7784             7132
# 4                   5/20/20          159820             6409             7606
#
#    NY Actual Deaths  NYC Total Cases  NYC Actual Cases  NYC Total Deaths  \
# 0              4260           138435            138435             14996
# 1               910           159865             21430             17589
# 2              1312           173288             13423             19297
# 3               650           185206             11918             20316
# 4               474           197611             12405             21003
#
# ...
