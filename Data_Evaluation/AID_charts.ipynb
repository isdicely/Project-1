# %%
# Import Dependencies
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import FixedLocator

# %%
# Import data
csv_path = "output_data/AID_processed_data.csv"
AID_data_file = pd.read_csv(csv_path)

covidtotal = pd.read_csv("Resources/covid_19_data.csv") 
covidtotal
# Out:
#                         Date  NY Total Cases  NY Actual Cases  \
# 0   Break 0: 1/22/20-4/22/20          114784           114784
# 1                    4/29/20          134850            20066
# 2                     5/6/20          145627            10777
# 3                    5/13/20          153411             7784
# 4                    5/20/20          159820             6409
# 5                    5/27/20          164997             5177
# 6                     6/3/20          169213             4216
# 7                    6/10/20          172038             2825
# 8                    6/17/20          174201             2163
# 9                    6/24/20          176318             2117
# 10                    7/1/20          178604             2286
# 11                    7/8/20          181152             2548
# 12                   7/15/20          184024             2872
# 13                   7/22/20          186442             2418
# ...

# %%
AID_df= pd.DataFrame(AID_data_file)
AID_df.drop(AID_df.columns[0], axis=1, inplace=True)
AID_df
# Out:
#    Reporting Date Start Period  End Period  United States  Female  Male  \
# 0      2020-04-29   2020-04-23  2020-05-05           35.9    40.7  31.0
# 1      2020-05-06   2020-04-23  2020-05-05           35.9    40.7  31.0
# 2      2020-05-13   2020-05-07  2020-05-12           34.4    37.2  31.4
# 3      2020-05-20   2020-05-14  2020-05-19           33.9    37.6  29.9
# 4      2020-05-27   2020-05-21  2020-05-26           34.3    38.1  30.3
# 5      2020-06-03   2020-05-28  2020-06-02           35.5    39.6  31.1
# 6      2020-06-10   2020-06-04  2020-06-09           36.1    40.0  31.9
# 7      2020-06-17   2020-06-11  2020-06-16           36.0    39.1  32.7
# 8      2020-06-24   2020-06-18  2020-06-23           36.1    39.6  32.4
# 9      2020-07-01   2020-06-25  2020-06-30           37.8    41.5  33.8
# 10     2020-07-08   2020-07-02  2020-07-07           39.0    41.3  36.5
# 11     2020-07-15   2020-07-09  2020-07-14           40.3    44.2  36.1
# ...

# %%
# ax = AID_df.plot(kind="bar", title = "IAD by age group", figsize=(15,10), legend=True,fontsize=12)
# ax.set_xlabel("Time", fontsize=12)
# ax.set_xlabel("Indicator Value", fontsize=12)
# plt.show()

# %%
# Data frame for US, NY and CA
AID_region_df = AID_df[["Reporting Date", "United States", "California", "New York"]]
# print(AID_region_df)
# Graph information in bar format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'rgbkymc'  #red, green, blue, black, etc.
    # Set bar graph
ax = AID_region_df.plot(kind='bar',figsize=(20,15),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=30)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_region_df.index))
ax.set_xticklabels(AID_region_df["Reporting Date"])
    # Add axis labels and titles
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time (By Region)", fontsize=20)
plt.legend(fontsize="x-large") # using a named size
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_Region_bar.png')

# %%
# Graph information in line format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'rgbkymc'  #red, green, blue, black, etc.
    # Set line graph
ax = AID_region_df.plot(kind='line',figsize=(20,15),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=32)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_region_df.index))
ax.set_xticklabels(AID_region_df["Reporting Date"])
    # Add axis labels and title
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time (By Region)", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
    # Rotate x-axis labels
_ = plt.xticks(rotation = 90)
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_Region_line.png')

# %%
# Data frame for Age groups
AID_age_groups_df = AID_df[["Reporting Date", "18 - 29 years", "30 - 39 years", "40 - 49 years", "50 - 59 years", "60 - 69 years", "70 - 79 years", "80 years and above"]]
AID_age_groups_df
# Out:
#    Reporting Date  18 - 29 years  30 - 39 years  40 - 49 years  50 - 59 years  \
# 0      2020-04-29           46.8           39.6           38.9           35.8
# 1      2020-05-06           46.8           39.6           38.9           35.8
# 2      2020-05-13           47.4           39.3           36.9           35.5
# 3      2020-05-20           47.7           37.8           35.3           33.7
# 4      2020-05-27           46.6           39.5           35.7           33.7
# 5      2020-06-03           49.3           40.6           36.9           33.6
# 6      2020-06-10           49.3           41.5           39.0           36.0
# 7      2020-06-17           48.7           40.3           38.4           35.8
# 8      2020-06-24           50.0           40.8           38.5           36.3
# 9      2020-07-01           49.4           44.1           39.7           37.4
# 10     2020-07-08           50.4           45.9           40.0           38.3
# ...

# %%
# Graph information in line format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'rgbkymc'  #red, green, blue, black, etc.
    # Set line graph
ax = AID_age_groups_df.plot(kind='line',figsize=(20,18),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=10)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_age_groups_df.index))
ax.set_xticklabels(AID_age_groups_df["Reporting Date"])
    # Add axis labels and title
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time (By Age Group)", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
    # Rotate x-axis labels
_ = plt.xticks(rotation = 90)
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_Age_Group_line.png')

# %%
# Data frame for Age groups
AID_gender_df = AID_df[["Reporting Date", "Female", "Male"]]
AID_gender_df
# Out:
#    Reporting Date  Female  Male
# 0      2020-04-29    40.7  31.0
# 1      2020-05-06    40.7  31.0
# 2      2020-05-13    37.2  31.4
# 3      2020-05-20    37.6  29.9
# 4      2020-05-27    38.1  30.3
# 5      2020-06-03    39.6  31.1
# 6      2020-06-10    40.0  31.9
# 7      2020-06-17    39.1  32.7
# 8      2020-06-24    39.6  32.4
# 9      2020-07-01    41.5  33.8
# 10     2020-07-08    41.3  36.5
# 11     2020-07-15    44.2  36.1
# 12     2020-07-22    44.6  37.0
# 13     2020-08-19    40.7  31.8
# 14     2020-08-26    40.7  31.8
# 15     2020-09-02    39.9  32.1
# 16     2020-09-09    39.9  32.1
# 17     2020-09-16    41.4  32.7
# 18     2020-09-23    41.4  32.7
# 19     2020-09-30    41.6  33.1
# 20     2020-10-07    41.6  33.1
# 21     2020-10-14    42.4  32.9
# 22     2020-10-21    42.4  32.9
# 23     2020-10-28    46.2  36.1
# 24     2020-11-04    46.2  36.1
# 25     2020-11-11    47.6  37.2
# 26     2020-11-18    47.6  37.2
# 27     2020-11-25    45.7  36.8
# ...

# %%
# Graph information in line format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'rgbkymc'  #red, green, blue, black, etc.
    # Set line graph
ax = AID_gender_df.plot(kind='line',figsize=(20,15),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=28)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_gender_df.index))
ax.set_xticklabels(AID_gender_df["Reporting Date"])
    # Add axis labels and title
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time (By Gender)", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
    # Rotate x-axis labels
_ = plt.xticks(rotation = 90)
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_Gender_line.png')

# %%
# Split region data frame into US and CA/NY
AID_region_df
# USA data frame
AID_US_df = AID_region_df[["Reporting Date","United States"]]
# CA/NY data frame
AID_CA_NY_df = AID_region_df[["Reporting Date","California", "New York"]]

# %%
# Graph information in bar format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'r'  #red
    # Set bar graph
ax = AID_US_df.plot(kind='bar',figsize=(20,15),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=32)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_US_df.index))
ax.set_xticklabels(AID_US_df["Reporting Date"])
    # Add axis labels and titles
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time In The United States", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_In_USA_bar.png')

# %%
# Graph information in line format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'r'  #red
    # Set line graph
ax = AID_US_df.plot(kind='line',figsize=(20,12),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=32)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_US_df.index))
ax.set_xticklabels(AID_gender_df["Reporting Date"])
    # Add axis labels and title
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time In The United States", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
    # Rotate x-axis labels
_ = plt.xticks(rotation = 90)
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_In_USA_line.png')

# %%
# Graph information in bar format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'gb'  #green, blue
    # Set bar graph
ax = AID_CA_NY_df.plot(kind='bar',figsize=(20,15),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=32)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_region_df.index))
ax.set_xticklabels(AID_CA_NY_df["Reporting Date"])
    # Add axis labels and titles
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time for CA and NY", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_CA_NY_bar.png')

# %%
# Graph information in line format for region
    # Set colors in this order, will keep from setting colors over an over again
my_colors = 'gb'  #green, blue
    # Set line graph
ax = AID_CA_NY_df.plot(kind='line',figsize=(20,12),legend=True, fontsize=14, color=my_colors)
fig = ax
    # Cut the y-axis to see the differences better
ax.set_ylim(bottom=32)
    # Include all data points in the x-axis
ax.xaxis.set_major_locator(FixedLocator(AID_CA_NY_df.index))
ax.set_xticklabels(AID_gender_df["Reporting Date"])
    # Add axis labels and title
ax.set_xlabel("Reporting Dates",fontsize=14)
ax.set_ylabel("IAD%",fontsize=16)
ax.set_title("Anxiety/Depression Trends Over Time for CA and NY", fontsize=20)
plt.legend(fontsize="xx-large") # using a named size
    # Rotate x-axis labels
_ = plt.xticks(rotation = 90)
# plt.show()
    # Save figure
plt.savefig('output_data/AID_Over_Time_By_CA_NY_line.png')
